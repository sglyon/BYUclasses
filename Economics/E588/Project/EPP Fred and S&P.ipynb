# %%
from byumcl.misc.pd_tools import df_to_latex
import pandas as pd
from pandas.io.data import DataReader, get_data_yahoo
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# Apply monkey patch to pandas DataFrame
pd.DataFrame.latex_form = lambda self, *args, **kwargs: df_to_latex(self, *args, **kwargs)

# %% [markdown]
# ## Gatheirng Data

# %%
def save_data():
    start = '1/1/2000'

    # Get S&P 500 data from yahoo
    sp500 = get_data_yahoo('^GSPC', start=start)['Adj Close']
    sp500.name = 'SP500'

    vix = get_data_yahoo('^VIX', start=start)['Adj Close']
    vix.name = 'VIX'

    # Get ten year and 3 month t-bill rates
    ten_yr = DataReader('DGS10', 'fred', start=start)
    three_mon = DataReader('DGS3MO', 'fred', start=start)

    ten_yr = ten_yr.ix[ten_yr.DGS10.str.count(r'^\.') != 1].astype(float)
    three_mon = three_mon.ix[three_mon.DGS3MO.str.count(r'^\.') != 1].astype(float)

    data = ten_yr.join(three_mon)
    data = data.join(sp500)
    data = data.join(vix)

    # Drop non-like observations (obs on different days)
    data = data.dropna()

    data.save('SP_YC.db')

# %%
# Load in the data we get from the save_data 
# save_data()
data = pd.DataFrame.load('SP_YC.db')
fred = data[['DGS10', 'DGS3MO']]
sp = data[['SP500', 'VIX']]

# %%
# Get description of the data
desc = data.describe()
print(desc)
# Out:
#              DGS10       DGS3MO        SP500          VIX
# count  3305.000000  3305.000000  3305.000000  3305.000000
# mean      3.993107     2.109943  1210.328711    21.805519
# std       1.140456     2.017721   187.526664     9.167021
# min       1.430000     0.000000   676.530000     9.890000
# 25%       3.380000     0.150000  1095.450000    15.540000
# 50%       4.120000     1.590000  1214.910000    20.030000
# 75%       4.740000     3.850000  1357.980000    25.400000
# max       6.790000     6.420000  1569.190000    80.860000

# %%
# Print the LaTeX form to paste into my paper
print(desc.latex_form(1, 1))
# Out:
# \begin{table}[ht]
# 	\begin{center}
# 		\begin{tabular}{rcccc}
# 		\toprule
# 			 & DGS10 & DGS3MO & SP500 & YC\\
# 			\midrule
# 			count & $3305$ & $3305$ & $3305$ & $3305$\\
# 			mean & $3.99311$ & $2.10994$ & $1210.33$ & $1.88316$\\
# 			std & $1.14046$ & $2.01772$ & $187.527$ & $1.28804$\\
# 			min & $1.43$ & $0$ & $676.53$ & $-0.95$\\
# 			25\% & $3.38$ & $0.15$ & $1095.45$ & $0.75$\\
# 			50\% & $4.12$ & $1.59$ & $1214.91$ & $2.09$\\
# 			75\% & $4.74$ & $3.85$ & $1357.98$ & $3.02$\\
# 			max & $6.79$ & $6.42$ & $1569.19$ & $3.85$\\
# 		\bottomrule
# 		\end{tabular}
# 	\end{center}
# \end{table}

# %% [markdown]
# ## Plot Data

# %%
# Plot FRED data
plt.figure()
fred.plot()
plt.ylabel('%')
plt.title('US Treasury Bill Time Series')
plt.savefig('./Figures/FRED_data.eps', format='eps', dpi=1000)

# Plot logged FRED data
plt.figure()
np.log(fred).plot()
plt.ylabel('%')
plt.title('Logged US Treasury Bill Time Series')
plt.savefig('./Figures/FRED_data_log.eps', format='eps', dpi=1000)

# Plot first differenced FRED data
plt.figure()
fred.diff(1).plot()
plt.ylabel('%')
plt.title('First Differenced US Treasury Bill Time Series')
plt.savefig('./Figures/FRED_data_diff.eps', format='eps', dpi=1000)

# %%
# Plot sp50 data
plt.figure()
sp.plot()
plt.ylabel('%')
plt.title('US Treasury Bill Time Series')
plt.savefig('./Figures/sp500_data.eps', format='eps', dpi=1000)

# Plot logged sp data
plt.figure()
np.log(sp).plot()
plt.ylabel('%')
plt.title('Logged US Treasury Bill Time Series')
plt.savefig('./Figures/sp500_data_log.eps', format='eps', dpi=1000)

# Plot first differenced sp data
plt.figure()
sp.diff(1).plot()
plt.ylabel('%')
plt.title('First Differenced US Treasury Bill Time Series')
plt.savefig('./Figures/sp500_data_diff.eps', format='eps', dpi=1000)

# %%
# Plot all data divided by its mean
(data / data.mean()).plot()
plt.savefig('./Figures/all_data.eps', format='eps', dpi=900)

# %%
def ac_pac(nlags=15):
    ac = [sm.tsa.stattools.acf(data['%s' % i].values, nlags=nlags) for i in data.columns]
    pac = [sm.tsa.stattools.pacf(data['%s' % i].values, nlags=nlags) for i in data.columns]

    corrs = pd.DataFrame(ac[0], columns=['DGS10ac'])
    corrs['DGS3ac'] = ac[1]
    corrs['SPac'] = ac[2]
    corrs['VIXac'] = ac[3]
    corrs['DGS10pac'] = pac[0]
    corrs['DGS3pac'] = pac[1]
    corrs['SPpac'] = pac[2]
    corrs['VIXpac'] = pac[3]

    return corrs

# %%
sm.tsa.stattools.acf?

# %%
corrs = ac_pac()

# %% [markdown]
# ##

# %%
# Plot the correlation and autocorrelation coefficients.
corrs = ac_pac(45)
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 5))

corrs[['DGS10ac', 'DGS10pac']].plot(ax=axes[0, 0])
axes[0, 0].set_title('Ten Year T-Bill (P)AC coefs')

corrs[['DGS3ac', 'DGS3pac']].plot(ax=axes[0, 1])
axes[0, 1].set_title('Three Month T-Bill (P)AC coefs')

corrs[['SPac', 'SPpac']].plot(ax=axes[1, 0])
axes[1, 0].set_title('S&P 500 (P)AC coefs')

corrs[['VIXac', 'VIXpac']].plot(ax=axes[1, 1])
axes[1, 1].set_title('VIX (P)AC coefs')

fig.subplots_adjust(hspace=0.3)
fig.savefig('./Figures/all_corrs.eps', format='eps', dpi=1000)

# %% [markdown]
# ## Identifying p, d, q

# %% [markdown]
# ### For SP500

# %%
def plot_diffs(ser, n=4, rows_cols=None, subplots=True):
    """
    Plot the first n differences of the pandas series ser
    """
    colors = ['k', 'b', 'g', 'c', 'k', 'm']
    df = pd.DataFrame(ser)
    names = ['d%i' % i for i in range(1, n + 1)]
    for i in range(n):
        df[names[i]] = ser.diff(i + 1)

    df = df.drop(ser.name, axis=1)

    if subplots:
        if rows_cols:
            rows, cols = rows_cols
        rem = n % (rows * cols)
        fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(8, 8))

        i = 0
        for r in range(rows):
            for c in range(cols):
                name = names[i]
                clr = colors[i]
                title = '%s: diff(%i)' % (ser.name, i + 1)
                if rows == 1 or cols == 1:
                    df[name].plot(ax=axes[r + c], xticks=[], use_index=False, color=clr)
                    axes[r + c].set_title(title)
                else:
                    df[name].plot(ax=axes[r, c], xticks=[], use_index=False, color=clr)
                    axes[r, c].set_title(title)
                i += 1
        #fig.subplots_adjust(hspace=0.5)

        if rem:
            plt.show()
            # Plot the remainder on separate axis
            name = names[i]
            title = '%s: diff(%i)' % (ser.name, i + 1)
            plt.figure()
            df[name].plot()
            plt.title(title)

    plt.show()

    # return df

# %%
arr1 = np.array([[i] * 4 for i in data.columns]).ravel()
arr2 = np.array([[1, 2, 3, 4] * 4])
arrays = np.row_stack([arr1, arr2])
# Out:
# [('DGS10', '1'),
#  ('DGS10', '2'),
#  ('DGS10', '3'),
#  ('DGS10', '4'),
#  ('DGS3MO', '1'),
#  ('DGS3MO', '2'),
#  ('DGS3MO', '3'),
#  ('DGS3MO', '4'),
#  ('SP500', '1'),
#  ('SP500', '2'),
#  ('SP500', '3'),
#  ('SP500', '4'),
#  ('VIX', '1'),
#  ('VIX', '2'),
#  ('VIX', '3'),
#  ('VIX', '4')]

# %%
arr1 = np.array([[i] * 4 for i in data.columns]).ravel()
arr2 = np.array([[1, 2, 3, 4] * 4])
arrays = np.row_stack([arr1, arr2])

tuples = zip(*arrays)
index = pd.MultiIndex.from_tuples(tuples, names=['DataSet', 'Lags'])
diffs = pd.DataFrame(columns=['Mean', 'Variance'], index=index)

# %%
diffs
# Out:
#              Mean Variance
# DataSet Lags
# DGS10   1     NaN      NaN
#         2     NaN      NaN
#         3     NaN      NaN
#         4     NaN      NaN
# DGS3MO  1     NaN      NaN
#         2     NaN      NaN
#         3     NaN      NaN
#         4     NaN      NaN
# SP500   1     NaN      NaN
#         2     NaN      NaN
#         3     NaN      NaN
#         4     NaN      NaN
# VIX     1     NaN      NaN
#         2     NaN      NaN
#         3     NaN      NaN
#         4     NaN      NaN

# %%
col = data.columns[0]

# %%
diffs.ix[col]
# Out:
#      Mean Variance
# Lags
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN

# %%
for col in data.columns:
    for i in range(1, 5):
        exec "d%i = data[col].diff(%i)" % (i, i)
        exec "mean = d%i.mean()" % (i)
        exec "var = d%i.var()" % (i)
        print('DataSet: %s, LAGS: %i, Mean:%.2e, Variance: %.2e' % (col, i, mean, var))
    plt.figure()
    plot_diffs(data[col], 4, (2, 2))
    plt.show()
# Out:
# DataSet: DGS10, LAGS: 1, Mean:-1.43e-03, Variance: 3.99e-03
# DataSet: DGS10, LAGS: 2, Mean:-2.82e-03, Variance: 7.98e-03
# DataSet: DGS10, LAGS: 3, Mean:-4.25e-03, Variance: 1.16e-02
# DataSet: DGS10, LAGS: 4, Mean:-5.66e-03, Variance: 1.52e-02
# DataSet: DGS3MO, LAGS: 1, Mean:-1.64e-03, Variance: 3.37e-03
# DataSet: DGS3MO, LAGS: 2, Mean:-3.25e-03, Variance: 7.77e-03
# DataSet: DGS3MO, LAGS: 3, Mean:-4.88e-03, Variance: 1.15e-02
# DataSet: DGS3MO, LAGS: 4, Mean:-6.50e-03, Variance: 1.41e-02
# DataSet: SP500, LAGS: 1, Mean:3.45e-02, Variance: 2.24e+02
# DataSet: SP500, LAGS: 2, Mean:8.40e-02, Variance: 4.06e+02
# DataSet: SP500, LAGS: 3, Mean:1.33e-01, Variance: 5.75e+02
# DataSet: SP500, LAGS: 4, Mean:1.78e-01, Variance: 7.48e+02
# DataSet: VIX, LAGS: 1, Mean:-3.48e-03, Variance: 3.13e+00
# DataSet: VIX, LAGS: 2, Mean:-7.68e-03, Variance: 5.36e+00
# DataSet: VIX, LAGS: 3, Mean:-1.18e-02, Variance: 7.26e+00
# DataSet: VIX, LAGS: 4, Mean:-1.54e-02, Variance: 9.02e+00

# %%
axes = data.diff(1).plot(subplots=0, yticks=[])
ax1 = axes[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-9b7c33c7d619> in <module>()
#       1 axes = data.diff(1).plot(subplots=0, yticks=[])
# ----> 2 ax1 = axes[0]
#
# TypeError: 'AxesSubplot' object does not support indexing

# %%
ax1.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-42fd50b5fd1c> in <module>()
# ----> 1 ax1.draw()
#
# TypeError: draw_wrapper() takes at least 2 arguments (1 given)

# %%
data.DGS10.plot(use_index=0)

# %%
data.v
