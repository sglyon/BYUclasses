# %% [markdown]
# ## Spencer Lyon
#
# ### Physics 430 Lab 3

# %%
# Import statements
from __future__ import division
import matplotlib.pyplot as plt
import scipy.linalg as la
import pandas as pd
import numpy as np
from tools import make_grid
import scipy.linalg as la

# plt.ion()  # Turn on interactive plotting in ipython

# Set pandas display options
pd.set_option('line_width', 180)
pd.set_option('max_columns', 100)
pd.set_option('precision', 5)
np.set_printoptions(suppress=1, precision=5, linewidth=180)
pd.set_option('chop', 1e-10)
pd.set_option('notebook', False)

# %% [markdown]
# #### Problem 3.1
#
# ##### Part a

# %%
def f_x(x):
    """
    implement the piecewise function in equation 3.4
    """
    x = np.ascontiguousarray(x)
    ret = np.zeros(x.size)
    for i in range(x.size):
        if 0.8 <= x[i] and x[i] < 1:
            ret[i] = 0.73

    return ret

# %%
# ------------------------------- Part a ------------------------------- #
# Define parameters
mu = 0.003
T = 127.0
L = 1.2
omega = 400

# Build grid
n = 50
xmin = 0
xmax = L
x, h = make_grid(xmin, xmax, n, 'cell_edge')

# Get data for function
y = f_x(x)

# Create the matrix representing A in the matrix equation for the BVP
A = np.zeros((n, n))  # Preallocate memory for A
A[0, 0] = 1  # Set first row of A
A[-1, -1] = 1  # Set last row of A

for i in xrange(1, n - 1):  # Fill in all other rows of A
    A[i, i - 1: i + 2] = [T / (h ** 2),
                          - 2 * T / (h ** 2) + mu * omega ** 2,
                          T / (h ** 2)]

# Create the vector representing x in the matrix equation for the BVP
x_approx = np.zeros(n)  # Preallocate memory for x_approx
x_approx[0] = 0  # Set first row of x_approx
x_approx[-1] = 0  # Set last row of x_approx
x_approx[1:-1] = -f_x(x[1:-1])  # Fill in all other rows of x_approx

# Approximate y
y_approx = la.solve(A, x_approx)

plt.figure()
plt.plot(x, y_approx, 'b--')
plt.title('Solution to part a with n = 100')
plt.show()

# %% [markdown]
# ##### Part b

# %%
omega_arr = np.linspace(400, 1200, 100)
iteration_data = pd.DataFrame(index=x)
maxes = np.zeros(100)
iteration_data.index.name = 'x'

for i in xrange(100):
    w = omega_arr[i]
    A2 = np.zeros((n, n))  # Preallocate memory for A2
    A2[0, 0] = 1  # Set first row of A2
    A2[-1, -1] = 1  # Set last row of A2

    for i in xrange(1, n - 1):  # Fill in all other rows of A2
        A2[i, i - 1: i + 2] = [T / (h ** 2),
                              - 2 * T / (h ** 2) + mu * w ** 2,
                              T / (h ** 2)]

    y_approx2 = la.solve(A2, x_approx)
    iteration_data[w] = y_approx2

iteration_data.columns.name = 'Omega'
plt.figure()
iteration_data.abs().max(0).plot()
plt.title('Solution to part b')
plt.show()

# %%
iteration_data.ix[:5,:5]
# Out:
# Omega     400.0000    408.0808    416.1616    424.2424    432.3232
# x
# 0.0000  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
# 0.0245  2.1253e-05  2.2669e-05  2.4282e-05  2.6134e-05  2.8279e-05
# 0.0490  4.2458e-05  4.5285e-05  4.8505e-05  5.2201e-05  5.6483e-05
# 0.0735  6.3567e-05  6.7794e-05  7.2608e-05  7.8135e-05  8.4537e-05
# 0.0980  8.4532e-05  9.0143e-05  9.6534e-05  1.0387e-04  1.1237e-04

# %%
iteration_data.ix[:5,:5].values
# Out:
# array([[-0.     , -0.     , -0.     ,  0.     , -0.     ],
#        [ 0.00002,  0.00002,  0.00002,  0.00003,  0.00003],
#        [ 0.00004,  0.00005,  0.00005,  0.00005,  0.00006],
#        [ 0.00006,  0.00007,  0.00007,  0.00008,  0.00008],
#        [ 0.00008,  0.00009,  0.0001 ,  0.0001 ,  0.00011]])

# %% [markdown]
# #### Problem 3.2
#
# ##### Parts a and b

# %%
mu = 0.003
T = 127
L = 1.2
omega = 400

# Build grid
n = 50
xmin = 0
xmax = L
x, h = make_grid(xmin, xmax, n, 'cell_edge')

# Create A matrix
A = np.zeros((n, n))
A[0, 0] = 1
A[-1, -1] = 1

for i in xrange(1, n - 1):  # Fill in all other rows of A
    A[i, i - 1: i + 2] = [1 / (h ** 2),
                          - 2 / (h ** 2),
                          1 / (h ** 2)]

# Create B matrix
B = np.eye(n)
B[0, 0] = 0
B[-1, -1] = 0

# Solve genearalized eigenvalue problem (eigen.m for python)
lamb, v1 = la.eig(A, B)

w2raw = - (T / mu) * lamb  # convert lambda to w ** 2
w2, k = [np.sort(w2raw), np.argsort(w2raw)]  # sort and get indices

num_plots = 3
plt.figure(figsize = (16, 3))

for i in range(num_plots):
    t = r'$\omega^2$ = %.3f, $\omega$ = %.3f' % (w2[i], np.sqrt(w2[i]))
    gn = v1[:, k[i]]
    w = (i + 1) * np.pi / L
    exact = np.sin(w * x)
    plt.subplot(1, num_plots, i + 1)
    plt.plot(x, gn, 'r.', x, exact, 'b-')
    plt.title(t)
    plt.xlabel('x')
    plt.ylabel('g(%i, x)' % (i + 1))
    plt.draw()
# Out:
# -c:37: ComplexWarning: Casting complex values to real discards the imaginary part
# /Users/spencerlyon2/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:320: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ##### Part c

# %%
# Get the first two frequencies
first_w = np.sqrt(w2[0]).real
second_w = np.sqrt(w2[1]).real


# Use the iteration_data object created in 3.1.b
maxes = iteration_data.max(0)
where_1 = np.where(maxes.index > first_w)[0][0]
where_2 = np.where(maxes.index > second_w)[0][0]
plt.figure(figsize=(14, 5))
plt.subplot(121)
plt.plot(maxes.index[where_1 - 5: where_1 + 5], maxes.ix[where_1 - 5: where_1 + 5])
plt.title(r'Around $\omega$ = %.3f' % first_w)
plt.xlabel(r'$\omega$')
plt.ylabel('Max Amplitude')

plt.subplot(122)
plt.plot(maxes.index[where_2 - 5: where_2 + 5], maxes.ix[where_2 - 5: where_2 + 5])
plt.title(r'Around $\omega$ = %.3f' % second_w)
plt.xlabel(r'$\omega$')
plt.ylabel('Max Amplitude')
plt.show()

# %% [markdown]
# #### Problem 3.2
#
# ##### Parts a and b

# %%
# ------------------------------- Part a ------------------------------- #
mu = 0.003
T = 127
L = 1.2
omega = 400

# Build grid
n = 100
xmin = 0
xmax = L
x, h = make_grid(xmin, xmax, n, 'cell_edge')

# Create A matrix
A = np.zeros((n, n))
A[0, 0] = 1
A[-1, -3:] = [1 / (2 * h), -2 / h, 3 / (2 * h)]

for i in xrange(1, n - 1):  # Fill in all other rows of A
    A[i, i - 1: i + 2] = [1 / (h ** 2),
                          - 2 / (h ** 2),
                          1 / (h ** 2)]

# Create B matrix
B = np.eye(n)
B[0, 0] = 0
B[-1, -1] = 0

# Solve genearalized eigenvalue problem (eigen.m for python)
lamb, v1 = la.eig(A, B)

w2raw = - (T / mu) * lamb  # convert lambda to w ** 2
w2, k = [np.sort(w2raw), np.argsort(w2raw)]  # sort and get indices

num_plots = 3
plt.figure(figsize = (16, 3))

for i in range(num_plots):
    t = r'$\omega^2$ = %.3f, $\omega$ = %.3f' \
        % (w2[i], np.sqrt(np.abs(w2[i])))
    gn = v1[:, k[i]]
    plt.subplot(1, num_plots, i + 1)
    plt.axis([0, L, -1, 1])
    plt.plot(x, gn, 'r.')
    plt.title(t)
    plt.xlabel('x')
    plt.ylabel('g(n, x)')
    plt.draw()
# Out:
# -c:39: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
# ------------------------------- Part b ------------------------------- #

# Create A matrix
A2 = np.zeros((n, n))
A2[0, 0] = 1
A2[-1, -3:] = [1 / (2 * h), -2 / h, 3 / (2 * h) - 2]

for i in xrange(1, n - 1):  # Fill in all other rows of A2
    A2[i, i - 1: i + 2] = [1 / (h ** 2),
                          - 2 / (h ** 2),
                          1 / (h ** 2)]

# Create B matrix
B = np.eye(n)
B[0, 0] = 0
B[-1, -1] = 0

# Solve genearalized eigenvalue problem (eigen.m for python)
lamb2, v12 = la.eig(A2, B)

w2raw2 = - (T / mu) * lamb2  # convert lambda to w ** 2
w22, k2 = [np.sort(w2raw2), np.argsort(w2raw2)]  # sort and get indices

num_plots = 3
plt.figure(figsize = (16, 3))

for i in range(num_plots):
    t = r'$\omega^2$ = %.3f, $\omega$ = %.3f' \
        % (w22[i], np.sqrt(np.abs(w22[i])))
    gn = v12[:, k2[i]]
    plt.subplot(1, num_plots, i + 1)
    plt.axis([0, L, -1, 1])
    plt.plot(x, gn, 'r.')
    plt.title(t)
    plt.xlabel('x')
    plt.ylabel('g(n, x)')
    plt.draw()
# Out:
# -c:29: ComplexWarning: Casting complex values to real discards the imaginary part
